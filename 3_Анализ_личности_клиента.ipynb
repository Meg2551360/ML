# %% [markdown]
# # Итоговый проект.

# %% [markdown]
# Анализ личности клиента — это подробный анализ клиентов компании. Он помогает компании лучше понять своих клиентов и облегчает изменение продукции в соответствии со специфическими потребностями, поведением различных типов клиентов.
#
# Анализ личности клиента помогает компании модифицировать свой продукт в соответствии с целевыми потребителями из различных сегментов потребителей. Например, вместо того, чтобы тратить деньги на маркетинг нового продукта для каждого клиента в базе данных компании, компания может проанализировать, какой сегмент клиентов с наибольшей вероятностью купит продукт, и затем продвигать продукт только для этого сегмента.
#
# Описание столбцов:
#
# |Название| Описание |
# |--|--|
# |ID| Уникальный идентификатор клиента|
# |Year_Birth| Год рождения клиента|
# |Education | Уровень образования клиента|
# |Marital_Status| Семейное положение клиента|
# |Income| Годовой доход семьи клиента|
# |Kidhome| Количество детей в семье клиента|
# |Teenhome| Количество подростков в домохозяйстве клиента|
# |Dt_Customer| Дата регистрации клиента в компании|
# |Recency| Количество дней с момента последней покупки клиента|
# |Complain| 1, если клиент жаловался в течение последних 2 лет, 0 —  в противном случае|
# |MntWines|  Сумма, потраченная на вино за последние 2 года|
# |MntFruits| Сумма, потраченная на фрукты за последние 2 года|
# |MntMeatProducts| Сумма, потраченная на мясо за последние 2 года|
# |MntFishProducts| Сумма, потраченная на рыбу за последние 2 года|
# |MntSweetProducts| Сумма, потраченная на сладости за последние 2 года|
# |MntGoldProds| Сумма, потраченная на золото за последние 2 года|
# |NumDealsPurchases| Количество покупок, совершенных со скидкой|
# |AcceptedCmp1| 1, если клиент принял предложение в 1-й кампании, 0 — иначе|
# |AcceptedCmp2| 1, если клиент принял предложение во 2-й компании, 0 — иначе|
# |AcceptedCmp3| 1, если клиент принял предложение в 3-й кампании, 0 — иначе|
# |AcceptedCmp4| 1, если клиент принял предложение в 4-й кампании, 0 — иначе|
# |AcceptedCmp5| 1, если клиент принял предложение в 5-й кампании, 0 — иначе|
# |Response| 1, если клиент принял предложение в последней кампании, 0 — иначе|
# |NumWebPurchases| Количество покупок, совершенных через веб-сайт компании|
# |NumCatalogPurchases| Количество покупок, сделанных с помощью каталога|
# |NumStorePurchases| Количество покупок, сделанных непосредственно в магазинах|
# |NumWebVisitsMonth| Количество посещений веб-сайта компании за последний месяц|

# %% [markdown]
# ## Задание
#
# Проведите полный цикл анализа данных (EDA), что проходили ранее. Этапы выполнения задания (наш pipeline):
#
# 1. Загрузка и предобработка данных. Очистить данные и удалить/заполнить пропуски.
# 2. Описательный анализ данных, просмотр данных и вывод статистик
# 3. Постройте необходимые графики для анализа
# 4. Проверьте гипотезы
# 5. Сделайте отчет-вывод по исследованию
#
# Что хочет узнать заказчик?
#
# 1. Сколько в среднем клиенты тратят на каждый тип товара? На какой товар надо сделать акцент?
# 2. Какой средний возраст покупателя? Зависит ли возраст клиента от его покупок во всех категориях?
# 3. Тратят ли клиент больше денег, если у него много детей и иждивенцев?
# 4. Зависят ли покупки от образования? Что предпочитают люди чаще покупать в зависимости от образования?
# 5. Женатые люди тратят больше или меньше денег на покупку золота?
# 6. Люди, которые покупают товар на сайте чаще берут что-то со скидкой?
# 7. Зависит ли жалоба клиента от его трат?
# 8. Люди, принявшие предложение о покупке лишь в последней компании тратят больше, чем люди, принявшие сразу предложение первой компании?
#
# **ЗАДАНИЕ ПРО**
#
# 1. Разбейте данные на несколько выборок: по образованию, по уровню заработка и по семейному статусу. Опишите все эти выборки и скажите — отличаются ли они между собой? Опишите общие закономерности для каждого типа — на что чаще тратит женатый человек и жалуется ли он? Люди с PhD покупают фрукты? И тд
# 2. Разбейте данные на две выборки — по сумме трат каждого товара: 1 — больше медианы трат, 0— меньше. Сравните выборки между собой и сделайте вывод — на кого надо опираться при модификации товаров магазинам?
# 3. Проведите дополнительный анализ, который поможет дать больше информации для заказчика.

# %% [markdown]
# ## Загрузка данных

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
from datetime import datetime

# %%
import re
df.columns = [re.sub(r'[ /?+@()%#]', '_', x.lower().strip()) for x in df.columns]

# %%
df = pd.read_csv(r'D:\Рабочий стол\Мэг_питон\1 раздел\marketing_campaign.csv', sep='\t')

# %%
df.sample(5)
# Out:
#         id  year_birth   education marital_status   income  kidhome  teenhome  \
# 748   2281        1970  Graduation         Single  33697.0        1         0
# 383   3310        1973    2n Cycle        Married  35688.0        2         1
# 1685  7947        1969  Graduation        Married  42231.0        1         1
# 1051  9725        1966         PhD       Together  28764.0        1         1
# 628   3469        1977         PhD       Divorced  34487.0        1         1
#
#      dt_customer  recency  mntwines  mntfruits  mntmeatproducts  \
# 748   15-09-2013       34         4          3                7
# 383   22-08-2012       94        73          3               90
# 1685  25-03-2014       99        24          0                8
# 1051  05-06-2014       16         8          0                3
# 628   06-09-2012       94        19         18               33
#
#       mntfishproducts  mntsweetproducts  mntgoldprods  numdealspurchases  \
# ...

# %%
df.shape # кол-во (строки, столбцы)
# Out:
# (2240, 29)

# %% [markdown]
# ## Описательный анализ данных

# %% [markdown]
# Рассмотрите данные — изучите медианы, средние, дисперсии и т.д.
#
# Что можете сказать о данных? Сделайте вывод.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2240 non-null   int64
#  1   year_birth           2240 non-null   int64
#  2   education            2240 non-null   object
#  3   marital_status       2240 non-null   object
#  4   income               2216 non-null   float64
#  5   kidhome              2240 non-null   int64
#  6   teenhome             2240 non-null   int64
#  7   dt_customer          2240 non-null   object
#  8   recency              2240 non-null   int64
#  9   mntwines             2240 non-null   int64
#  10  mntfruits            2240 non-null   int64
#  11  mntmeatproducts      2240 non-null   int64
#  12  mntfishproducts      2240 non-null   int64
#  13  mntsweetproducts     2240 non-null   int64
#  14  mntgoldprods         2240 non-null   int64
# ...

# %% [markdown]
# Всего 2240 строк, 29 столбцов, из которых 3 имеют тип `object` (Education, Marital_Status, Dt_Customer), 1 - `float64` (Income), остальные 25 - `int64`. Объем датафрейма 507.6+ KB

# %%
df.Income.idxmax (axis= 0) # обнаружен выброс Income = 666666. (обнаружено через боксплот) 
#Такое редко афишируют/вряд ли в среднестатистическом районе обитает миллионер, иначе у компании явно была бы другая клиентская база
# Out:
# 2233

# %%
df = df.drop (index= 2233)

# %%
df.describe()
# Out:
#                  ID   Year_Birth         Income      Kidhome     Teenhome  \
# count   2239.000000  2239.000000    2215.000000  2239.000000  2239.000000
# mean    5590.444841  1968.802144   51969.861400     0.443948     0.506476
# std     3246.372471    11.985494   21526.320095     0.538390     0.544555
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2827.500000  1959.000000   35284.000000     0.000000     0.000000
# 50%     5455.000000  1970.000000   51373.000000     0.000000     0.000000
# 75%     8423.500000  1977.000000   68487.000000     1.000000     1.000000
# max    11191.000000  1996.000000  162397.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2239.000000  2239.000000  2239.000000      2239.000000
# mean     49.121036   304.067441    26.307727       167.016525
# std      28.963662   336.614830    39.781468       225.743829
# ...

# %% [markdown]
# expenses в среднем 606(медиана 396.5), min = 5, max = 2525

# %% [markdown]
# **Вывод:**
# - Большая часть клиентов 1970 года рождения(53 года)
# - Среднестатистический годовой доход семьи 51969, min = 1730, max = 162397
# - Количество дней с момента последней покупки клиента в среднем 49, min = 0, max = 99
# - Сумма, потраченная за последние 2 года:
#     - на `вино` в среднем = 304 (медиана 174), max = 1493
#     - на `фрукты` в среднем = 26 (медиана 8), max = 199
#     - на `мясо` в среднем = 167 (медиана 67), max = 1725
#     - на `рыбу` в среднем = 37 (медиана 12), max = 259
#     - на `сладости` в среднем = 27 (медиана 8), max = 263
#     - на `золото` в среднем = 44 (медиана 24), max = 362
# - Количество покупок, совершенных `со скидкой` в среднем = 2 , max = 15
# - Количество покупок, сделанных `непосредственно в магазинах` в среднем = 5 , max = 13
# - Количество покупок, сделанных `с помощью каталога` в среднем = 2 , max = 28
# - Количество покупок, совершенных `через веб-сайт` компании в среднем = 4 , max = 27
# - Количество посещений веб-сайта компании за последний месяц в среднем = 5 (медиана 6) , max = 20

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# Предобработайте датасет — проверьте на наличие дубликатов и удалите, если они есть.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Year_Birth, Education, Marital_Status, Income, Kidhome, Teenhome, Dt_Customer, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, AcceptedCmp3, AcceptedCmp4, AcceptedCmp5, AcceptedCmp1, AcceptedCmp2, Complain, Z_CostContact, Z_Revenue, Response]
# Index: []

# %% [markdown]
# ### Отсутствующие значения

# %% [markdown]
# Предобработайте датасет — проверьте на наличие NaN и удалите или заполните значения.

# %%
df.isna().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %%
df.Income = df.Income.fillna(df.Income.median()) 	
# обнаружено 24 пропуска, заменим годовой доход семьи клиента медианой

# %% [markdown]
# ### Изменение типа данных

# %% [markdown]
# Рассмотрев все данные, замените типы на нужные (при необходимости):
#
# - Если есть числа — на `int` или `float`
# - Если категории — можно оставить `object`

# %% [markdown]
# Нет необходимости

# %%
df.Marital_Status.value_counts()
# Out:
# Marital_Status
# Married     864
# Together    579
# Single      480
# Divorced    232
# Widow        77
# Alone         3
# Absurd        2
# YOLO          2
# Name: count, dtype: int64

# %%
df.Marital_Status = df.Marital_Status.str.replace("Alone", "Single") # заменили на равнозначное значение
df.Marital_Status = df.Marital_Status.str.replace("Absurd", "Single")
df.Marital_Status = df.Marital_Status.str.replace("YOLO", "Single")

# %%
df.Education.value_counts()
# Out:
# Education
# Graduation    1126
# PhD            486
# Master         370
# 2n Cycle       203
# Basic           54
# Name: count, dtype: int64

# %%
today = pd.to_datetime('today')
df['age'] = today.year - df['Year_Birth']

# %%
def calculate_c(c_date):
    today = datetime.now()
    age = today.year - c_date.year - ((today.month, today.day) <
                                          (c_date.month, c_date.day))
    return age

d1 = pd.to_datetime(df['Dt_Customer'], format='mixed')
df['how_long_ago'] = d1.apply(calculate_c)
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      5524        1957  Graduation         Single  58138.0        0
# 1      2174        1954  Graduation         Single  46344.0        1
# 2      4141        1965  Graduation       Together  71613.0        0
# 3      6182        1984  Graduation       Together  26646.0        1
# 4      5324        1981         PhD        Married  58293.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10870        1967  Graduation        Married  61223.0        0
# 2236   4001        1946         PhD       Together  64014.0        2
# 2237   7270        1981  Graduation       Divorced  56981.0        0
# 2238   8235        1956      Master       Together  69245.0        0
# 2239   9405        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# ...

# %%
df.age.idxmax (axis= 0)
# Out:
# 239

# %%
df = df.drop (index= 239) # 130 лет

# %%
df = df.drop (index= 339) # 124 года

# %%
df = df.drop (index= 192) # 123 года - возможно, но многовато, + меньше 10% от датасета - могу себе позволить

# %%
df.age.max()
# Out:
# 83

# %%
df = df.reset_index(drop=True) # сброс индексов

# %%
df['expenses'] = df.MntWines + df.MntFruits + df.MntMeatProducts + df.MntFishProducts + df.MntSweetProducts + df.MntGoldProds
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      5524        1957  Graduation         Single  58138.0        0
# 1      2174        1954  Graduation         Single  46344.0        1
# 2      4141        1965  Graduation       Together  71613.0        0
# 3      6182        1984  Graduation       Together  26646.0        1
# 4      5324        1981         PhD        Married  58293.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2231  10870        1967  Graduation        Married  61223.0        0
# 2232   4001        1946         PhD       Together  64014.0        2
# 2233   7270        1981  Graduation       Divorced  56981.0        0
# 2234   8235        1956      Master       Together  69245.0        0
# 2235   9405        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# ...

# %% [markdown]
# ## Визуализация

# %%
df.hist(figsize=(15, 20))
# Out:
# array([[<Axes: title={'center': 'ID'}>,
#         <Axes: title={'center': 'Year_Birth'}>,
#         <Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Kidhome'}>,
#         <Axes: title={'center': 'Teenhome'}>],
#        [<Axes: title={'center': 'Recency'}>,
#         <Axes: title={'center': 'MntWines'}>,
#         <Axes: title={'center': 'MntFruits'}>,
#         <Axes: title={'center': 'MntMeatProducts'}>,
#         <Axes: title={'center': 'MntFishProducts'}>],
#        [<Axes: title={'center': 'MntSweetProducts'}>,
#         <Axes: title={'center': 'MntGoldProds'}>,
#         <Axes: title={'center': 'NumDealsPurchases'}>,
#         <Axes: title={'center': 'NumWebPurchases'}>,
#         <Axes: title={'center': 'NumCatalogPurchases'}>],
#        [<Axes: title={'center': 'NumStorePurchases'}>,
#         <Axes: title={'center': 'NumWebVisitsMonth'}>,
#         <Axes: title={'center': 'AcceptedCmp3'}>,
#         <Axes: title={'center': 'AcceptedCmp4'}>,
# ...

# %% [markdown]
# - средний возраст большинства покупателей в районе 45-60 лет
# - годовой доход 45000-60000
# - у большинства нет или только 1 ребенок/подросток
# - основная масса людей тратит на вино не более 300 т. р. за 2 года (около 1000 чел), на фрукты до 30 (1450 чел.), на мясо до 180 (свыше 1500 чел.), на рыбу до 30 (1400 чел.), на сладкое до 30 (1550 чел.), около 30 на золото (1350)
# - большая часть покупок совершается через каталог (1300 чел., кажд. из кот. берет по 2 продукта) и веб-сайт (800 чел. - 4, более 400 чел - 6), в магазине - неравномерное распределение, веб сайт в среднем посещают 5-6 раз (700 чел.)
# - новых клиентов не зарегистрировано, подавляющее число - это постоянные (на протяжении 9/10 лет) покупатели (*P.s.: ребята, с этим надо что-то делать)

# %%
sns.boxplot(df, orient= 'h')
# Out:
# <Axes: >

# %% [markdown]
# ## Задание от заказчика

# %% [markdown]
# 1. Сколько в среднем клиенты тратят на каждый тип товара? На какой товар надо сделать акцент?
# 2. Какой средний возраст покупателя? Зависит ли возраст клиента от его покупок во всех категориях?
# 3. Тратят ли клиент больше денег, если у него много детей и иждивенцев?
# 4. Зависят ли покупки от образования? Что предпочитают люди чаще покупать в зависимости от образования?
# 5. Женатые люди тратят больше или меньше денег на покупку золота?
# 6. Люди, которые покупают товар на сайте чаще берут что-то со скидкой?
# 7. Зависит ли жалоба клиента от его трат?
# 8. Люди, принявшие предложение о покупке лишь в последней компании тратят больше, чем люди, принявшие сразу предложение первой компании?

# %%
mnt_products = df.loc[:, ['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds']]
mnt_products
# Out:
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# 0          635         88              546              172                88
# 1           11          1                6                2                 1
# 2          426         49              127              111                21
# 3           11          4               20               10                 3
# 4          173         43              118               46                27
# ...        ...        ...              ...              ...               ...
# 2231       709         43              182               42               118
# 2232       406          0               30                0                 0
# 2233       908         48              217               32                12
# 2234       428         30              214               80                30
# 2235        84          3               61                2                 1
#
#       MntGoldProds
# ...

# %%
plt.figure(figsize=(10,7))
sns.boxplot(mnt_products)
# Out:
# <Axes: >

# %% [markdown]
# Большая часть трат приходится на вино(медиана в районе 180, верхняя граница 1240) и мясо(медиана 70, верхняя граница 550), приобретаются в том числе и по высокой цене (см. выбросы). Верхняя граница остальных продуктов не превышает 100

# %%
def age_cat(row):
    if row < 18:
        return "children"
    elif row >= 18 and row < 35:
        return "adult"
    elif row >= 35 and row < 60:
        return "mature"
    else:
        return "elderly"

# %%
df['age_category'] = df['age'].apply(age_cat)
df['age_category'].value_counts()
# Out:
# age_category
# mature     1404
# elderly     741
# adult        91
# Name: count, dtype: int64

# %%
for col in mnt_products.select_dtypes(include='number'):
    plt.figure(figsize=(7, 5))
    plt.title(f'Гистограмма {col}')
    sns.histplot(x = col, hue = 'age_category', bins = 20, kde = True, data = df)

# %% [markdown]
# 2. Основная категория покупателей 35-60 лет, около 800 чел приобретают фрукты, мясо, рыбу, сладости, более 600 вино и золото, выбирают товары по невысокой цене. Однако возрастная группа >60 лет предпочитают более дорогие продукты (главным образом вина)

# %%
sns.heatmap(df[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'Kidhome', 'Teenhome']].corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# 3. Наблюдается отрицательная корреляция при наличии детей, меньшая - с подростками

# %%
df.groupby(by=['Education'], as_index=False).agg(MntWines_median = ('MntWines','median'),
                                                 MntFruits_median = ('MntFruits','median'),
                                                 MntMeatProducts__median = ('MntMeatProducts','median'),
                                                 MntFishProducts_median = ('MntFishProducts','median'),
                                                 MntSweetProducts_median = ('MntSweetProducts','median'),
                                                 MntGoldProds_median = ('MntGoldProds','median')) 
# 4 см. pro
# Out:
#     Education  MntWines_median  MntFruits_median  MntMeatProducts__median  \
# 0    2n Cycle             51.0              13.0                     47.0
# 1       Basic              2.0               7.0                      7.0
# 2  Graduation            183.5              10.0                     78.5
# 3      Master            179.0               6.0                     63.5
# 4         PhD            269.0               4.0                     69.0
#
#    MntFishProducts_median  MntSweetProducts_median  MntGoldProds_median
# 0                    19.0                      9.0                 28.0
# 1                     9.0                      7.0                 15.0
# 2                    15.0                     12.0                 29.0
# 3                     8.0                      6.0                 20.0
# 4                     6.0                      3.0                 16.0

# %%
sns.histplot(x = 'MntGoldProds', hue = 'Marital_Status', bins = 20, kde = True, data = df)
# Out:
# <Axes: xlabel='MntGoldProds', ylabel='Count'>

# %% [markdown]
# 5. Да, женатые люди тратят больше денег на покупку золота

# %%
df[['NumWebPurchases', 'NumDealsPurchases']].corr() # 6. сильной корреляции не наблюдается
# Out:
#                    NumWebPurchases  NumDealsPurchases
# NumWebPurchases           1.000000           0.233971
# NumDealsPurchases         0.233971           1.000000

# %% [markdown]
# 6. Корреляции между покупкой товара 'на сайте' и 'по скидке' нет

# %%
plt.title('Жалобы и кол-во трат')
sns.boxplot(data = df, x= 'Complain', y = 'expenses')
# Out:
# <Axes: title={'center': 'Жалобы и кол-во трат'}, xlabel='Complain', ylabel='expenses'>

# %% [markdown]
# 7. Жалобы оставляют люди, которые меньше тратят

# %%
s_1 = df.loc[df['AcceptedCmp1'] == 1]
s_1.expenses.sum()
# Out:
# 213440

# %%
sns.histplot(x = 'expenses', bins = 20, kde = True, data = s_1)
# Out:
# <Axes: xlabel='expenses', ylabel='Count'>

# %%
s_5 = df.loc[df['AcceptedCmp5'] == 1]
s_5.expenses.sum()
# Out:
# 261573

# %%
sns.histplot(x = 'expenses', bins = 20, kde = True, data = s_5)
# Out:
# <Axes: xlabel='expenses', ylabel='Count'>

# %%
plt.figure(figsize=(13,9))
sns.heatmap(df[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 
                'AcceptedCmp1','AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4','AcceptedCmp5', 'age', 'expenses', 'Income']].corr(), annot = True, cmap = 'plasma')
# Out:
# <Axes: >

# %% [markdown]
# Корреляция наблюдается между
# - вином и мясом (0.56)
# - тратами и: выбором 5 компании (0.47), вином(0.89), мясом (0.84). Большой доход не означает больше трат на золото
# - при покупке рыбы, вероятно также приобретение фруктов, сладостей и мяса

# %% [markdown]
# 8. Да, люди, принявшие предложение о покупке лишь в последней компании тратят больше, чем люди, принявшие сразу предложение первой компании

# %% [markdown]
# ### ЗАДАНИЕ ПРО
#
# 1. Разбейте данные на несколько выборок: по образованию, по уровню заработка и по семейному статусу. Опишите все эти выборки и скажите — отличаются ли они между собой? Опишите общие закономерности для каждого типа — на что чаще тратит женатый человек и жалуется ли он? Люди с PhD покупают фрукты? И тд
# 2. Разбейте данные на две выборки — по сумме трат каждого товара: 1 — больше медианы трат, 0 — меньше. Сравните выборки между собой и сделайте вывод — на кого надо опираться при модификации товаров магазинам?
# 3. Проведите дополнительный анализ, который поможет дать больше информации для заказчика.

# %%
# по уровню заработка
def income_cat(row):
    if row < 40000:
        return "below_the_average"
    elif row >= 40000 and row < 65000:
        return "middle"
    elif row >= 65000 and row < 10000:
        return "above_average"
    else:
        return "high"
    
df['income_category'] = df['Income'].apply(income_cat)

# %%
plt.title('Образование и уровень зароботка')
sns.countplot(data=df, x = 'Education', hue = 'income_category', palette = 'Set3')
# Out:
# <Axes: title={'center': 'Образование и уровень зароботка'}, xlabel='Education', ylabel='count'>

# %% [markdown]
# Graduation, PhD, Master имеют средний ур(др. ур. не искл.). зароботка, у 2n Cycle чуть превышает ниже среднего, у кого базовое образование - зароботок только ниже среднего

# %%
plt.title('Семейное положение и уровень зароботка')
sns.countplot(data=df, x = 'Marital_Status', hue = 'income_category', palette = 'Set1')
# Out:
# <Axes: title={'center': 'Семейное положение и уровень зароботка'}, xlabel='Marital_Status', ylabel='count'>

# %%
def plot_box(data, col, ax, name):
    sns.boxplot(data = data, x = 'Marital_Status', y =  col, ax= ax, palette = 'Set1')
    ax.set_title(name)
    plt.show

fig, axes = plt.subplots(3, 2,  figsize=(13, 15))
fig.suptitle('Сравнительные диаграммы размаха \n по семейному положению:')
plot_box(df, 'MntWines', axes[0,0], 'Вино')
plot_box(df, 'MntFruits', axes[0,1], 'Фрукты')
plot_box(df, 'MntMeatProducts', axes[1,0], 'Мясо')
plot_box(df, 'MntFishProducts', axes[1,1], 'Рыба')
plot_box(df, 'MntSweetProducts', axes[2,0], 'Сладости')
plot_box(df, 'MntGoldProds', axes[2,1], 'Золото')

# %%
sns.pairplot(df[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'Marital_Status']], corner=True, hue= 'Marital_Status') # внесем немного хаоса

# %% [markdown]
# Основной контенгент женатые (осебенно по винами), пары и одиночки
#
# Вдовы покупают больше фруктов, вина (средн цены), рыбу и сладости.
# Одиночки делают упор на рыбу, разведенные - на вино

# %%
def plot_box(data, col, ax, name):
    sns.boxplot(data = data, x = 'Education', y =  col, ax= ax, palette = 'Set3')
    ax.set_title(name)
    plt.show

fig, axes = plt.subplots(3, 2,  figsize=(13, 15))
fig.suptitle('Сравнительные диаграммы размаха \n в зависимости от образования:')
plot_box(df, 'MntWines', axes[0,0], 'Вино')
plot_box(df, 'MntFruits', axes[0,1], 'Фрукты')
plot_box(df, 'MntMeatProducts', axes[1,0], 'Мясо')
plot_box(df, 'MntFishProducts', axes[1,1], 'Рыба')
plot_box(df, 'MntSweetProducts', axes[2,0], 'Сладости')
plot_box(df, 'MntGoldProds', axes[2,1], 'Золото')

# %% [markdown]
# 4.Вино (более дорогое) преимущественно предпочитают философы.
# С базовым образование потребляют фрукты, рыбу, сладости, весомая доля приобретения дешёвого вина и мяса (среди остальных групп по образованию).
# Выпускники представляют собой большую группу, равномерно рапред траты по всем категориям товаров, но упор на рыбу, вино и фрукты (с любой ценой)

# %%
sns.pairplot(df[['MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'Education']], corner=True, hue= 'Education')

# %%
# разделили по сумме трат на 2 выборки
df['MntWines_median'] = (df['MntWines'] >= df['MntWines'].median()).astype(int)
df['MntFruits_median'] = (df['MntFruits'] >= df['MntFruits'].median()).astype(int)
df['MntMeatProducts_median'] = (df['MntMeatProducts'] >= df['MntMeatProducts'].median()).astype(int)
df['MntFishProducts_median'] = (df['MntFishProducts'] >= df['MntFishProducts'].median()).astype(int)
df['MntSweetProducts_median'] = (df['MntSweetProducts'] >= df['MntSweetProducts'].median()).astype(int)
df['MntGoldProds_median'] = (df['MntGoldProds'] >= df['MntGoldProds'].median()).astype(int)
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      5524        1957  Graduation         Single  58138.0        0
# 1      2174        1954  Graduation         Single  46344.0        1
# 2      4141        1965  Graduation       Together  71613.0        0
# 3      6182        1984  Graduation       Together  26646.0        1
# 4      5324        1981         PhD        Married  58293.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2231  10870        1967  Graduation        Married  61223.0        0
# 2232   4001        1946         PhD       Together  64014.0        2
# 2233   7270        1981  Graduation       Divorced  56981.0        0
# 2234   8235        1956      Master       Together  69245.0        0
# 2235   9405        1954         PhD        Married  52869.0        1
#
#       Teenhome Dt_Customer  Recency  MntWines  MntFruits  MntMeatProducts  \
# ...

# %%
def gr(col):
    sns.countplot(data=df, x = 'Education', hue = col, palette='Pastel2')

gr('MntWines_median')

# %%
gr('MntFruits_median')

# %%
gr('MntMeatProducts_median')

# %%
gr('MntFishProducts_median')

# %%
gr('MntSweetProducts_median')

# %%
gr('MntGoldProds_median')

# %% [markdown]
# Выше среднего тратят на вино Graduation, PhD и Master, на мясо Graduation и PhD, на остальное Graduation и 2n Cycle

# %% [markdown]
# # Общий вывод

# %% [markdown]
# - Средний возраст клиентов около 53 лет
# - Основной акцент нужно сделать на
#      1. вина: траты в среднем = 304 (медиана 174), max = 1493, его чаще покупают Graduation, более дорогие - `PhD`, по семейному положению -все, преимущественно `Married`(в т.ч. более дорогие), Together и Single, по возрасту `elderly`(б. дорогие) и mature.
#      2. мясо: среднем = 167 (медиана 67), max = 1725. Больший доход будет за счет Graduation и PhD.
# - Люди, принявшие предложение о покупке в 5-ой компании тратят больше, чем люди, принявшие сразу предложение первой компании
